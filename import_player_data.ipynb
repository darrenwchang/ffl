# %% [markdown]
# # Import Player Data
#
# * Quick pass at using `nfl_data_py` to import data
# * Quick visualizations

# %%
# %pip install nfl_data_py
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 684.3/684.3 kB 6.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 10.4 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 7.8 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import nfl_data_py as nfl

# %%
years = [2019, 2020, 2021, 2022, 2023]

# %%
dat = nfl.import_weekly_data(years, downcast = True)
# Out:
# Downcasting floats.

# %%
dat.head()
# Out:
#     player_id player_name player_display_name position position_group  \
# 0  00-0019596     T.Brady           Tom Brady       QB             QB
# 1  00-0019596     T.Brady           Tom Brady       QB             QB
# 2  00-0019596     T.Brady           Tom Brady       QB             QB
# 3  00-0019596     T.Brady           Tom Brady       QB             QB
# 4  00-0019596     T.Brady           Tom Brady       QB             QB
#
#                                         headshot_url recent_team  season  \
# 0  https://static.www.nfl.com/image/private/f_aut...          NE    2019
# 1  https://static.www.nfl.com/image/private/f_aut...          NE    2019
# 2  https://static.www.nfl.com/image/private/f_aut...          NE    2019
# 3  https://static.www.nfl.com/image/private/f_aut...          NE    2019
# 4  https://static.www.nfl.com/image/private/f_aut...          NE    2019
#
#    week season_type  ... receiving_first_downs  receiving_epa  \
# ...

# %%
# do i need to scrape for adp?
# interesting that points follow log normal distribution
# lots of censoring (no <0 values)

# yes need to scrape for ADP
# also gets proj pts to have baseline for model
# roll each year - 2019 = base year, then iterate thru with rolling training dat

# %%
dat.to_csv('data/player_data.csv', index=False)
